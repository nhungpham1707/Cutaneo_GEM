# %%
import cobra as cb #Version 0.8.0
import os
import re
import sys
from copy import deepcopy

# %%
model = cb.io.read_sbml_model('test_final3.xml')

# %%
model.metabolites
# Out:
# [<Metabolite 37671__ce at 0x115c0cc10>,
#  <Metabolite 37671__c at 0x115c0cbd0>,
#  <Metabolite 37671__e at 0x10cb8bf50>,
#  <Metabolite 27380__ce at 0x115c0cc50>,
#  <Metabolite 27380__c at 0x115c0cc90>,
#  <Metabolite 49258__m at 0x115c0ccd0>,
#  <Metabolite C04411__c at 0x115c0cd10>,
#  <Metabolite C04823__c at 0x115c0cd50>,
#  <Metabolite 17214__c at 0x115c0cd90>,
#  <Metabolite 17214__m at 0x115c0cdd0>,
#  <Metabolite 15607__m at 0x115c0ce10>,
#  <Metabolite 53026__c at 0x115c0ce50>,
#  <Metabolite 53026__n at 0x115c0ce90>,
#  <Metabolite methf__c at 0x115c0cf10>,
#  <Metabolite methf__m at 0x115c0cf90>,
#  <Metabolite 15682__c at 0x115c0cfd0>,
#  <Metabolite 23dhmb__m at 0x11421bfd0>,
#  <Metabolite 15905__c at 0x11421bd90>,
#  <Metabolite 15899__c at 0x11421bc50>,
#  <Metabolite 17436__c at 0x11421bd10>,
#  <Metabolite 15686__c at 0x115c24050>,
#  <Metabolite 16347__c at 0x115c24090>,
#  <Metabolite 16347__m at 0x115c24110>,
#  <Metabolite 16347__x at 0x115c24190>,
# ...
